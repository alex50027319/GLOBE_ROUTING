# %% [markdown]
# # Lite-GLOBE Phase 5: Local PPO Fine-tuning
# Phase 4 checkpoint가 없으면 먼저 offline distillation을 실행한다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %%
from pathlib import Path
if not Path('artifacts/lite_globe/student_phase4.pt').exists():
    # !python -m implementations.lite_globe.run_phase4 --device auto

# %%
# !python -m pytest tests/lite_globe -q

# %%
# !python -m implementations.lite_globe.run_phase5 --device auto --evaluation-episodes 100
