# %% [markdown]
# # Lite-GLOBE Phase 4: Offline Policy Distillation
# Phase 3 checkpoint가 없으면 gated Teacher를 먼저 재학습한다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %%
# !python -m pytest tests/lite_globe -q

# %%
# !python -m implementations.lite_globe.run_phase4 --device auto --evaluation-episodes 100
