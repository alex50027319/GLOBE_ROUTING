# %% [markdown]
# # Lite-GLOBE Phase 3: Global Teacher
# Google Drive에 `ResearchAIWorkspace`를 올린 뒤 아래 경로를 맞춘다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %%
# !python -m pytest tests/lite_globe -q

# %%
# !python -m implementations.lite_globe.run_phase3 --device auto --evaluation-episodes 100 --checkpoint artifacts/lite_globe/teacher_phase3.pt
