# %% [markdown]
# # Phase 11 Lite-GLOBE-P\n\nPhase 8 Geo-Residual KD를 기반으로 predictive link-lifetime prior, bounded residual, risk-gated penalty를 결합한 Lite-GLOBE-P를 학습하고 평가합니다. 실행 전에 `ResearchAIWorkspace` 폴더와 Phase 7/Phase 8 체크포인트가 Google Drive에 있어야 합니다.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace\n!python -m pip install -q -r requirements-lite-globe.txt\n!python -m pip install -q -e .

# %% [markdown]
# ## Smoke run\n\n먼저 짧은 smoke run으로 checkpoint 경로와 실행 환경을 확인합니다.

# %%
# !python -m implementations.lite_globe.run_phase11 --smoke --resume --output-dir artifacts/lite_globe/phase11_smoke

# %% [markdown]
# ## Full run\n\n최종 학습과 평가는 아래 셀을 실행합니다. GPU 런타임을 권장합니다.

# %%
# !python -m implementations.lite_globe.run_phase11 --resume --output-dir artifacts/lite_globe/phase11

# %% [markdown]
# ## Package results\n\n아래 zip 파일을 로컬로 내려받으면 됩니다.

# %%
# !zip -r phase11_lite_globe_p_results.zip artifacts/lite_globe/phase11 > /dev/null\n!ls -lh phase11_lite_globe_p_results.zip
