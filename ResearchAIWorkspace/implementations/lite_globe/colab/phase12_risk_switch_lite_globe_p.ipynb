# %% [markdown]
# # Phase 12 Risk-Switch Lite-GLOBE-P\n\nPhase 8 Geo-Residual KD와 Phase 11 predictive-prior branch를 결합한 최종 후보 정책을 calibration하고 평가합니다. 일반 상황에서는 Phase 8 branch를 사용하고, local link-break risk가 높은 경우에만 predictive-prior branch로 전환합니다.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace\n!python -m pip install -q -r requirements-lite-globe.txt\n!python -m pip install -q -e .

# %% [markdown]
# ## Smoke run

# %%
# !python -m implementations.lite_globe.run_phase12 --smoke --resume --output-dir artifacts/lite_globe/phase12_smoke

# %% [markdown]
# ## Full run

# %%
# !python -m implementations.lite_globe.run_phase12 --resume --output-dir artifacts/lite_globe/phase12

# %% [markdown]
# ## Package results

# %%
# !zip -r phase12_risk_switch_results.zip artifacts/lite_globe/phase12 > /dev/null\n!ls -lh phase12_risk_switch_results.zip
