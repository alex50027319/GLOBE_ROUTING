# %% [markdown]
# # Lite-GLOBE Phase 6: Multi-seed Evaluation
# 5개 학습 seed, 4개 평가 scenario, 7개 방법을 비교하고 논문용 표와 그래프를 생성한다. 중단 후 재실행할 때 `--resume`이 완료된 seed checkpoint를 재사용한다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %%
import torch
print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('gpu:', torch.cuda.get_device_name(0))

# %%
# !python -m pytest tests/lite_globe -q

# %%
# !python -m implementations.lite_globe.run_phase6 \
  --device auto \
  --resume \
  --output-dir artifacts/lite_globe/phase6

# %%
from pathlib import Path
from IPython.display import Markdown, display
display(Markdown(Path('artifacts/lite_globe/phase6/tables/main_results.md').read_text()))
display(Markdown(Path('artifacts/lite_globe/phase6/tables/ood_results.md').read_text()))

# %%
from IPython.display import Image, display
display(Image('artifacts/lite_globe/phase6/figures/pdr_comparison.png'))
display(Image('artifacts/lite_globe/phase6/figures/ood_pdr.png'))

# %%
# !zip -qr artifacts/lite_globe/phase6_results.zip artifacts/lite_globe/phase6
print('Saved: artifacts/lite_globe/phase6_results.zip')
