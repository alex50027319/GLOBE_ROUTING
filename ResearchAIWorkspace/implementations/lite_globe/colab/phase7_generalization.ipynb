# %% [markdown]
# # Lite-GLOBE Phase 7: Generalization and Validity Hardening
# 고정 routing-hole을 벗어나 동적 topology curriculum에서 학습하고, held-out topology family와 Oracle 기준으로 검증한다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/ResearchAIWorkspace-Colab
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %%
import torch
print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('gpu:', torch.cuda.get_device_name(0))

# %%
# !python -m pytest tests/lite_globe -q

# %%
# !python -m implementations.lite_globe.run_phase7 \
  --device auto \
  --resume \
  --output-dir artifacts/lite_globe/phase7

# %%
from pathlib import Path
from IPython.display import Markdown, Image, display
base = Path('artifacts/lite_globe/phase7')
display(Markdown((base/'tables/generalization_results.md').read_text()))
display(Markdown((base/'tables/unconditional_results.md').read_text()))
display(Image(str(base/'figures/generalization_pdr.png')))

# %%
# !zip -qr artifacts/lite_globe/phase7_results.zip artifacts/lite_globe/phase7
print('Saved: artifacts/lite_globe/phase7_results.zip')
