# %% [markdown]
# # SwitchGLOBE
#
# PPO Teacher, Geo-Residual Student, Predictive Student를 학습한 뒤 최종 위험 전환 정책을 보정하고 평가합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/SwitchGLOBE
# !python -m pip install -q -r requirements-lite-globe.txt
# !python -m pip install -q -e .

# %% [markdown]
# ## Smoke: full training lineage

# %%
# !python scripts/train_switchglobe_pipeline.py --device cuda --smoke --resume

# %% [markdown]
# ## Full five-seed run

# %%
# !python scripts/train_switchglobe_pipeline.py --device cuda --resume

# %% [markdown]
# ## Package verified artifacts

# %%
# !zip -r switchglobe_results.zip artifacts/switchglobe/final > /dev/null
# !ls -lh switchglobe_results.zip
